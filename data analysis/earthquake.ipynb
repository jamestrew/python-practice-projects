# %%
import pandas as pd

# %%
df = pd.read_csv('data/earthquake.csv', index_col='earthquake_id')

# %%
df
# Out:
#                        occurred_on  latitude  longitude   depth  magnitude  \
# earthquake_id
# 1               1969-01-01 9:07:06   51.0960  -179.3920   45.00        5.6
# 2              1969-01-02 17:50:48  -56.0960   -27.8420   80.10        6.0
# 3               1969-01-03 3:16:40   37.1400    57.8990   10.00        5.5
# 4              1969-01-03 13:28:12   51.1320  -179.3060   15.00        5.9
# 5              1969-01-04 22:36:48   -6.8500   129.8210  105.00        5.8
# ...                            ...       ...        ...     ...        ...
# 23115          2018-12-26 14:11:22  -17.2789  -174.0153  120.00        5.7
# 23116           2018-12-28 3:03:33   -1.4521   134.0850   41.00        5.7
# 23117           2018-12-29 3:39:10    5.8983   126.9209   60.21        7.0
# 23118           2018-12-30 8:39:12   -2.6772   102.3490  166.00        5.7
# 23119           2018-12-31 2:35:38   54.4266  -161.5131   31.00        6.0
#
#               calculation_method       network_id  \
# ...
